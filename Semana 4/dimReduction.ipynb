# %% [markdown]
# # Dimension Reduction

# %%
import pandas as pd

# %%
BostonHousing = 'https://raw.githubusercontent.com/tec03/Datasets/main/datasets/BostonHousing.csv'

# %% [markdown]
# #### Variables
#
# There are 14 attributes in each case of the dataset. They are:
#
# * CRIM - per capita crime rate by town
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * NOX - nitric oxides concentration (parts per 10 million)
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per \$10,000
# * PTRATIO - pupil-teacher ratio by town
# * B - 1000(Bk - 0.63)$^2$ where Bk is the proportion of blacks by town
# * LSTAT - % lower status of the population
# * MEDV - Median value of owner-occupied homes in $1000's

# %%
bostonHousing_df = pd.read_csv(BostonHousing)
df = bostonHousing_df.copy()
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT. MEDV
# 0   4.98  24.0          0
# 1   9.14  21.6          0
# 2   4.03  34.7          1
# 3   2.94  33.4          1
# 4   5.33  36.2          1

# %%
df = df.rename(columns={'CAT. MEDV': 'CAT_MEDV'})
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT_MEDV
# 0   4.98  24.0         0
# 1   9.14  21.6         0
# 2   4.03  34.7         1
# 3   2.94  33.4         1
# 4   5.33  36.2         1

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# Compute mean, standard deviation, min, max, median, length, and missing values of CRIM

# %%
print('Mean \t: ', df.CRIM.mean())
print('Std.dev \t: ', df.CRIM.std())
print('Min \t: ', df.CRIM.min())
print('Max \t: ', df.CRIM.max())
print('Median \t: ', df.CRIM.median())
print('Length \t: ', len(df.CRIM))
print('Number of missing values : ', df.CRIM.isnull().sum())
# Out:
# Mean 	:  3.613523557312254
# Std.dev 	:  8.60154510533249
# Min 	:  0.00632
# Max 	:  88.9762
# Median 	:  0.25651
# Length 	:  506
# Number of missing values :  0

# %% [markdown]
# Compute mean, standard dev., min, max, median, length, and missing values for all variables

# %%
pd.DataFrame({'mean': df.mean(),
              'sd': df.std(),
              'min': df.min(),
              'max': df.max(),
              'median': df.median(),
              'length': len(df),
              'miss.val': df.isnull().sum(),
             })
# Out:
#                 mean          sd        min       max     median  length  \
# CRIM        3.613524    8.601545    0.00632   88.9762    0.25651     506
# ZN         11.363636   23.322453    0.00000  100.0000    0.00000     506
# INDUS      11.136779    6.860353    0.46000   27.7400    9.69000     506
# CHAS        0.069170    0.253994    0.00000    1.0000    0.00000     506
# NOX         0.554695    0.115878    0.38500    0.8710    0.53800     506
# RM          6.284634    0.702617    3.56100    8.7800    6.20850     506
# AGE        68.574901   28.148861    2.90000  100.0000   77.50000     506
# DIS         3.795043    2.105710    1.12960   12.1265    3.20745     506
# RAD         9.549407    8.707259    1.00000   24.0000    5.00000     506
# TAX       408.237154  168.537116  187.00000  711.0000  330.00000     506
# PTRATIO    18.455534    2.164946   12.60000   22.0000   19.05000     506
# LSTAT      12.653063    7.141062    1.73000   37.9700   11.36000     506
# ...

# %% [markdown]
# ## Relationships between two or more variables

# %%
df.corr().round(2)
# Out:
#           CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  \
# CRIM      1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58
# ZN       -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31
# INDUS     0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72
# CHAS     -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04
# NOX       0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67
# RM       -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29
# AGE       0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51
# DIS      -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53
# RAD       0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91
# TAX       0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00
# PTRATIO   0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46
# LSTAT     0.46 -0.41   0.60 -0.05  0.59 -0.61  0.60 -0.50  0.49  0.54
# ...

# %% [markdown]
# # Aggregation
#
# For `aggregation` by a single variable, we can use the pandas method `value_counts()`.

# %%
df.CHAS.value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %% [markdown]
# The `groupby()` method can be used for:
# * aggregating by one or more variables, and
# * computing a range of summary statistics (count, mean, median, etc.).
#
#
# Create `bins of size 1` for variable using the method `pd.cut`.
#
# Use cut when you need to segment and sort data values into bins. This function is also useful for going from a continuous variable to a categorical variable.
#
# For example:
# * cut could convert ages to groups of age ranges.
# * RM - average number of rooms per dwelling -> convert to categorical variable
# * By default, the method creates a categorical variable, e.g. (6,7].
# * The argument `labels=False` determines integers instead, e.g. 6.

# %%
df['RM_bin'] = pd.cut(df.RM,
                      range(0, 10), # bins range
                      labels=False #If False (array or False, default None), returns only integer indicators of the bins.
                      )
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV  CAT_MEDV  RM_bin
# 0       15.3   4.98  24.0         0       6
# ...

# %%
#df[df.RM <=5]

# %%
print(df.RM_bin.unique())
print(df.RM.unique())
# Out:
# [6 7 5 8 4 3]
# [6.575 6.421 7.185 6.998 7.147 6.43  6.012 6.172 5.631 6.004 6.377 6.009
#  5.889 5.949 6.096 5.834 5.935 5.99  5.456 5.727 5.57  5.965 6.142 5.813
#  5.924 5.599 6.047 6.495 6.674 5.713 6.072 5.95  5.701 5.933 5.841 5.85
#  5.966 6.595 7.024 6.77  6.169 6.211 6.069 5.682 5.786 6.03  5.399 5.602
#  5.963 6.115 6.511 5.998 5.888 7.249 6.383 6.816 6.145 5.927 5.741 6.456
#  6.762 7.104 6.29  5.787 5.878 5.594 5.885 6.417 5.961 6.065 6.245 6.273
#  6.286 6.279 6.14  6.232 5.874 6.727 6.619 6.302 6.167 6.389 6.63  6.015
#  6.121 7.007 7.079 6.405 6.442 6.249 6.625 6.163 8.069 7.82  7.416 6.781
#  6.137 5.851 5.836 6.127 6.474 6.229 6.195 6.715 5.913 6.092 6.254 5.928
#  6.176 6.021 5.872 5.731 5.87  5.856 5.879 5.986 5.613 5.693 6.431 5.637
#  6.458 6.326 6.372 5.822 5.757 6.335 5.942 6.454 5.857 6.151 6.174 5.019
#  5.403 5.468 4.903 6.13  5.628 4.926 5.186 5.597 6.122 5.404 5.012 5.709
#  6.129 6.152 5.272 6.943 6.066 6.51  6.25  7.489 7.802 8.375 5.854 6.101
# ...

# %% [markdown]
# #### Compute the average of MEDV by (binned) RM and CHAS.
#
# *  MEDV - Median value of owner-occupied homes in \$1000's
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * RM - average number of rooms per dwelling
#
# First group the data frame using the groupby method, then restrict the analysis to MEDV and determine the mean for each group.

# %%
df.groupby(['RM_bin', 'CHAS'])['MEDV'].mean()
# Out:
# RM_bin  CHAS
# 3       0       25.300000
# 4       0       15.407143
# 5       0       17.200000
#         1       22.218182
# 6       0       21.769170
#         1       25.918750
# 7       0       35.964444
#         1       44.066667
# 8       0       45.700000
#         1       35.950000
# Name: MEDV, dtype: float64

# %% [markdown]
# # Pivot Tables
#
# Use `pivot_table()` to reshape data and generate pivot table

# %%
import numpy as np

# %%
pd.pivot_table(df, 
               values='MEDV', 
               index=['RM_bin'], 
               columns=['CHAS'],
               aggfunc=np.mean, 
               margins=True
               )
# Out:
# CHAS            0          1        All
# RM_bin
# 3       25.300000        NaN  25.300000
# 4       15.407143        NaN  15.407143
# 5       17.200000  22.218182  17.551592
# 6       21.769170  25.918750  22.015985
# 7       35.964444  44.066667  36.917647
# 8       45.700000  35.950000  44.200000
# All     22.093843  28.440000  22.532806

# %%
# use pivot_table() to reshape data and generate pivot table
pd.pivot_table(df, 
               values='MEDV', 
               index=['RM_bin', 'CHAS'],
               aggfunc=np.mean, 
               margins=True
               )
# Out:
#                   MEDV
# RM_bin CHAS
# 3      0     25.300000
# 4      0     15.407143
# 5      0     17.200000
#        1     22.218182
# 6      0     21.769170
#        1     25.918750
# 7      0     35.964444
#        1     44.066667
# 8      0     45.700000
#        1     35.950000
# All          22.532806

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT_MEDV  RM_bin
# 0   4.98  24.0         0       6
# 1   9.14  21.6         0       6
# 2   4.03  34.7         1       7
# 3   2.94  33.4         1       6
# 4   5.33  36.2         1       7

# %% [markdown]
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.

# %%
df.groupby(['ZN'])['ZN'].mean().to_frame()
# Out:
#           ZN
# ZN
# 0.0      0.0
# 12.5    12.5
# 17.5    17.5
# 18.0    18.0
# 20.0    20.0
# 21.0    21.0
# 22.0    22.0
# 25.0    25.0
# 28.0    28.0
# 30.0    30.0
# 33.0    33.0
# 34.0    34.0
# 35.0    35.0
# 40.0    40.0
# 45.0    45.0
# 52.5    52.5
# 55.0    55.0
# 60.0    60.0
# 70.0    70.0
# 75.0    75.0
# 80.0    80.0
# 82.5    82.5
# 85.0    85.0
# 90.0    90.0
# 95.0    95.0
# 100.0  100.0

# %% [markdown]
# Use method `crosstab` to create a cross-tabulation of two variables
#
# * MEDV - Median value of owner-occupied homes in $1000's
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# Method `crosstab`:
# * by default, computes a frequency table

# %%
tbl = pd.crosstab(df.CAT_MEDV, 
                  df.ZN
                  )
tbl
# Out:
# ZN        0.0    12.5   17.5   18.0   20.0   21.0   22.0   25.0   28.0   \
# CAT_MEDV
# 0           339     10      0      1      5      4      9     10      3
# 1            33      0      1      0     16      0      1      0      0
#
# ZN        30.0   ...  55.0   60.0   70.0   75.0   80.0   82.5   85.0   90.0   \
# CAT_MEDV         ...
# 0             6  ...      2      3      3      1     10      1      2      0
# 1             0  ...      1      1      0      2      5      1      0      5
#
# ZN        95.0   100.0
# CAT_MEDV
# 0             0      0
# 1             4      1
#
# [2 rows x 26 columns]

# %%
# use pivot_table(); alternative way
pd.pivot_table(df, 
               values='AGE', 
               index=['CAT_MEDV','ZN'],
               aggfunc='count', 
               ).transpose()
# Out:
# CAT_MEDV     0                                                        ...  \
# ZN       0.0   12.5  18.0  20.0  21.0  22.0  25.0  28.0  30.0  33.0   ...
# AGE        339    10     1     5     4     9    10     3     6     2  ...
#
# CAT_MEDV     1
# ZN       40.0  45.0  55.0  60.0  75.0  80.0  82.5  90.0  95.0  100.0
# AGE          4     5     1     1     2     5     1     5     4     1
#
# [1 rows x 39 columns]

# %%
# convert numbers to ratios
propTbl = tbl / tbl.sum()
propTbl = propTbl.round(2)
propTbl
# Out:
# ZN        0.0    12.5   17.5   18.0   20.0   21.0   22.0   25.0   28.0   \
# CAT_MEDV
# 0          0.91    1.0    0.0    1.0   0.24    1.0    0.9    1.0    1.0
# 1          0.09    0.0    1.0    0.0   0.76    0.0    0.1    0.0    0.0
#
# ZN        30.0   ...  55.0   60.0   70.0   75.0   80.0   82.5   85.0   90.0   \
# CAT_MEDV         ...
# 0           1.0  ...   0.67   0.75    1.0   0.33   0.67    0.5    1.0    0.0
# 1           0.0  ...   0.33   0.25    0.0   0.67   0.33    0.5    0.0    1.0
#
# ZN        95.0   100.0
# CAT_MEDV
# 0           0.0    0.0
# 1           1.0    1.0
#
# [2 rows x 26 columns]

# %%
import matplotlib.pyplot as plt

# %%
# plot the ratios in a stacked bar chart
ax = propTbl.transpose().plot(kind='bar', 
                              stacked=True, 
                              figsize = (15,10)
                              )

ax.xaxis.set_tick_params(labelsize='xx-large')
ax.yaxis.set_tick_params(labelsize='xx-large')

ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])

plt.xlabel('ZN', fontsize=18)

plt.title('Distribution of CAT.MEDV by ZN', fontsize = 24)

plt.legend(loc='center left', 
           bbox_to_anchor=(1, 0.5),
           fontsize = 24
           )

plt.show()
# Out:
# /var/folders/vn/dz88q3d90njcf56flzg996140000gn/T/ipykernel_28420/454702387.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in ax.get_yticks()])

# %% [markdown]
# ### Similar bars indicate low separation between classes, and can be combined

# %%
print('*'*55,'End','*'*55)
# Out:
# ******************************************************* End *******************************************************
